# %%
import warnings
warnings.filterwarnings('ignore', 
    message='.*Attempting to register factory for plugin.*')
warnings.filterwarnings('ignore',
    message='.*computation placer already registered.*')

import os
os.chdir('/app/NBT-Classifier/')
import glob
import numpy as np
import pandas as pd

import openslide
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt 

from utils import *
from utils_vis import plot_oneline, show_roi, patch_overlay_wsi

# %% [markdown]
# ### Load WSI & foreground tissue mask

# %%
wsi_pt = '../examples/QuPath/17064108_FPE_1.ndpi'
require_bounds = ".mrxs" in wsi_pt 
mask_pt = '../examples/17064108_FPE_1.ndpi_mask_use.png'

# %%
wsi = openslide.OpenSlide(wsi_pt)
im_wsi = wsi.read_region((0,0), wsi.level_count-1, wsi.level_dimensions[wsi.level_count-1]).convert('RGB')
im_mask = Image.open(mask_pt)
plot_oneline([im_wsi, im_mask], ['wsi', 'foreground'], (10,10))

# %% [markdown]
# ### Whole slide tissue classification

# %%
# parameters
foreground_thes = 0.7
patch_size_microns = 128
model_type = 'TC_512'
IMAGE_SIZE = (512, 512)
free_space = False 
use_multithreading = True
max_workers = 8

# %%
# load model
model_weights = './data/TC_512px.h5'
model = get_TC(model_weights, image_size=IMAGE_SIZE, num_classes=3, output_features=False)
# Out:
# /cephfs/volumes/hpc_data_prj/cb_histology_data/8b8186f5-4ae0-4605-94c4-46d4ff4e62b0/Siyuan/Docker_test/nbtclassifier/NBT-Classifier/utils.py:41: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   net = MobileNet(include_top=False, input_shape=(image_size[0], image_size[1], 3))
# I0000 00:00:1746528008.587018 2135062 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3234 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB MIG 1g.5gb, pci bus id: 0000:17:00.0, compute capability: 8.0

# %%
# output dir
wsi_name = "17064108_FPE_1"
output_dir = os.path.join("../project/FEATUREs", wsi_name)
os.makedirs(output_dir, exist_ok=True)

# %%
# Convert physical patch size (microns) to pixel dimensions using WSI's MPP resolution
patch_size, _ = parse_patch_size(wsi, patch_size_microns)
print(patch_size)
# Out:
# 579

# %%
# make WSI-level tissue classification 
TC_maskpt = os.path.join(output_dir, f"{wsi_name}_{model_type}_probmask.npy")
tissue_map = run_TC_one_slide(wsi, mask_pt, TC_maskpt, patch_size, foreground_thes, IMAGE_SIZE, model, free_space, use_multithreading, max_workers)

tc_map_path = os.path.join(output_dir, f"{wsi_name}_{model_type}.png")
save_tc_map(tissue_map, wsi_pt, tc_map_path)
# Out:
# Mask saved at ../examples/17064108_FPE_1.ndpi_mask_use.npy.
# Preprocessing ../project/FEATUREs/17064108_FPE_1/17064108_FPE_1_TC_512...
# Extracting patches from 17064108_FPE_1_TC_512_pattern: 100%|███████| 18753/18753 [07:57<00:00, 39.28it/s]
# Tiles extracted for 17064108_FPE_1_TC_512_pattern: 18753 patches saved.
# Vectorization completed for ../project/FEATUREs/17064108_FPE_1/17064108_FPE_1_TC_512.
# Predicting tissue classes...
# /scratch/users/k21066795/conda/nbtclassifier/lib/python3.9/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746529317.715737 2135441 service.cc:152] XLA service 0x76bf9c001e60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746529317.715763 2135441 service.cc:160]   StreamExecutor device (0): NVIDIA A100-SXM4-40GB MIG 1g.5gb, Compute Capability 8.0
# 2025-05-06 12:01:57.739289: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1746529318.063407 2135441 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-05-06 12:01:59.397965: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_667', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-05-06 12:01:59.607969: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_667_0', 184 bytes spill stores, 412 bytes spill loads
#
# 2025-05-06 12:01:59.897208: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_674', 4880 bytes spill stores, 6024 bytes spill loads
#
# 2025-05-06 12:01:59.955586: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_681', 272 bytes spill stores, 272 bytes spill loads
#
# 2025-05-06 12:02:00.013215: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_667', 136 bytes spill stores, 136 bytes spill loads
#
# 2025-05-06 12:02:00.300833: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_667', 4372 bytes spill stores, 4348 bytes spill loads
#
# 2025-05-06 12:02:00.375106: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_674_0', 212 bytes spill stores, 416 bytes spill loads
#
# 2025-05-06 12:02:00.490249: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_667', 3836 bytes spill stores, 3832 bytes spill loads
#
# 2025-05-06 12:02:00.590098: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_674', 212 bytes spill stores, 236 bytes spill loads
#
# 2025-05-06 12:02:00.603231: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_681', 220 bytes spill stores, 220 bytes spill loads
#
# 2025-05-06 12:02:00.665920: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_674', 3116 bytes spill stores, 3092 bytes spill loads
#
# 2025-05-06 12:02:00.762056: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_674', 4 bytes spill stores, 4 bytes spill loads
#    3/2345 ━━━━━━━━━━━━━━━━━━━━ 1:41 43ms/step
# I0000 00:00:1746529328.442203 2135441 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2345/2345 ━━━━━━━━━━━━━━━━━━━━ 129s 50ms/step
# Processing Patches: 100%|█████████████████████████████████████| 18753/18753 [00:00<00:00, 1258331.46it/s]
# Tissue map saved at ../project/FEATUREs/17064108_FPE_1/17064108_FPE_1_TC_512_probmask.npy.
# TC Map saved at ../project/FEATUREs/17064108_FPE_1/17064108_FPE_1_TC_512.png.

# %% [markdown]
# ### Whole slide tissue class heatmaps

# %%
# Compare tissue classification confidence thresholds by masking low-confidence regions:
# - For thresholds [0.7, 0.9, 0.95, 0.99], set RGB=0 where confidence < threshold
# - Input: `tissue_map` (np.array[H,W,3]) with channels representing:
#   - Red: Epithelium confidence
#   - Green: Stroma confidence  
#   - Blue: Adipocytes confidence
# - Output: 2x2 grid of thresholded images (colored regions = high-confidence tissue, black = masked)

images = []
thresholds = [0.7, 0.9, 0.95, 0.99]
for threshold in thresholds:
    im = tissue_map.copy()
    im[:,:, 0][tissue_map[:,:, 0] < threshold] = 0
    im[:,:, 1][tissue_map[:,:, 1] < threshold] = 0
    im[:,:, 2][tissue_map[:,:, 2] < threshold] = 0
    images.append(im)


fig, axs = plt.subplots(2, 2, figsize=(8, 8))
counter = 0
for x in range(2):
    for y in range(2):
        axs[x, y].imshow(images[counter])
        axs[x, y].set_title(f'threshold: {thresholds[counter]}')
        axs[x, y].axis('off') 
        counter += 1
plt.tight_layout()
plt.show()

# %%
# save all classified patches
Allpatch_pt = f"{output_dir}/{wsi_name}_{model_type}_patch_all.csv"
cls_df = save_Allpatch(tissue_map, patch_size, Allpatch_pt)
# Out:
# ../project/FEATUREs/17064108_FPE_1/17064108_FPE_1_TC_512_patch_all.csv saved!

# %%
# convert into a .json file as pseudo annotation for the use of QuPath 
json_pt = f"{output_dir}/{wsi_name}_{model_type}_cls_wsi.json"
get_JSON(cls_df, json_pt, patch_size, require_bounds)
cls_df.head()
# Out:
# ../project/FEATUREs/17064108_FPE_1/17064108_FPE_1_TC_512_cls_wsi.json saved!
#                  patch_id  grid_x  grid_y  orig_x  orig_y  TC_epi  TC_str  \
# 0  17064108_FPE_1_0_0_579       0       0       0       0     0.0     0.0
# 1  17064108_FPE_1_0_1_579       0       1       0     579     0.0     0.0
# 2  17064108_FPE_1_0_2_579       0       2       0    1158     0.0     0.0
# 3  17064108_FPE_1_0_3_579       0       3       0    1737     0.0     0.0
# 4  17064108_FPE_1_0_4_579       0       4       0    2316     0.0     0.0
#
#    TC_adi  cls    cohort          wsi_id
# 0     0.0    0  FEATUREs  17064108_FPE_1
# 1     0.0    0  FEATUREs  17064108_FPE_1
# 2     0.0    0  FEATUREs  17064108_FPE_1
# 3     0.0    0  FEATUREs  17064108_FPE_1
# 4     0.0    0  FEATUREs  17064108_FPE_1

# %% [markdown]
# ## Lobule binary mask

# %%
upscale_factor = 32
small_objects=400000
roi_width = 250

# %%
epi_mask, roi_width, wsi_mask_ratio = process_TCmask(wsi, tissue_map, upscale_factor, small_objects, roi_width)
epi_mask_pt = f"{output_dir}/{os.path.basename(wsi_pt)}_epi_({int(wsi_mask_ratio)},0,0,{epi_mask.shape[1]},{epi_mask.shape[0]})-mask.png"
save_epi_mask(epi_mask, epi_mask_pt)
plt.imshow(epi_mask, cmap = 'gray')
plt.axis("off")
# Out:
# ../project/FEATUREs/17064108_FPE_1/17064108_FPE_1.ndpi_epi_(18,0,0,8704,6208)-mask.png saved!
# (-0.5, 8703.5, 6207.5, -0.5)

# %% [markdown]
# ## ROI detection

# %%
patch_pt = f"{output_dir}/{wsi_name}_{model_type}_patch_roi.csv"
patch_df = save_ROIpatch(tissue_map, epi_mask, wsi_mask_ratio, roi_width, patch_size, patch_pt)
# Out:
# There're 81 ROIs detected
# Saved ../project/FEATUREs/17064108_FPE_1/17064108_FPE_1_TC_512_patch_roi.csv!

# %%
overlay_path = f"{output_dir}/{wsi_name}_{model_type}_bbx.png"
bbx_map = bbx_overlay(epi_mask, overlay_path, roi_width)
plt.imshow(bbx_map)
plt.axis('off')
# Out:
# Saved ../project/FEATUREs/17064108_FPE_1/17064108_FPE_1_TC_512_bbx.png!
# (-0.5, 8703.5, 6207.5, -0.5)

# %%
wsi_id = "17064108_FPE_1"
# get roi ids for all ROIs detected on the WSI
roi_ids = get_roi_ids(epi_mask, wsi_id, roi_width, wsi_mask_ratio)

## display a single ROI
im = show_roi(wsi, roi_ids[3])
plt.imshow(im)
plt.axis('off')
# Out:
# There're 81 ROIs detected
# (-0.5, 9184.5, 8604.5, -0.5)

# %%
json_pt = f"{output_dir}/{wsi_name}_{model_type}_cls_roi.json"
get_JSON(patch_df, json_pt, patch_size, require_bounds)
patch_df.head()
# Out:
# ../project/FEATUREs/17064108_FPE_1/17064108_FPE_1_TC_512_cls_roi.json saved!
#                                  roi_id  \
# 0  17064108_FPE_1_94248_25256_6286_5127
# 1  17064108_FPE_1_94248_25256_6286_5127
# 2  17064108_FPE_1_94248_25256_6286_5127
# 3  17064108_FPE_1_94248_25256_6286_5127
# 4  17064108_FPE_1_94248_25256_6286_5127
#
#                                           patch_id  cls    TC_epi    TC_str  \
# 0  17064108_FPE_1_94248_25256_6286_5127_165_46_579    1  0.962391  0.037592
# 1  17064108_FPE_1_94248_25256_6286_5127_166_46_579    1  0.875106  0.124794
# 2  17064108_FPE_1_94248_25256_6286_5127_167_46_579    1  0.990265  0.009713
# 3  17064108_FPE_1_94248_25256_6286_5127_165_47_579    1  0.965307  0.034632
# 4  17064108_FPE_1_94248_25256_6286_5127_166_47_579    1  0.945871  0.053913
#
#      TC_adi    cohort          wsi_id  orig_x  orig_y
# 0  0.000017  FEATUREs  17064108_FPE_1   95535   26634
# 1  0.000100  FEATUREs  17064108_FPE_1   96114   26634
# 2  0.000022  FEATUREs  17064108_FPE_1   96693   26634
# 3  0.000061  FEATUREs  17064108_FPE_1   95535   27213
# 4  0.000216  FEATUREs  17064108_FPE_1   96114   27213

# %% [markdown]
# ## Targeted patch selection

# %%
num2sample = 1500
sampled_patches = []
for cls in [1, 2, 3]:
    df_cls = patch_df[patch_df["cls"] == cls]
    df_cls_shuffled = df_cls.sample(frac=1, random_state=42)
    df_cls_sampled = df_cls_shuffled.head(num2sample)
    sampled_patches.append(df_cls_sampled)

patch_sampled = pd.concat(sampled_patches, ignore_index=True)
print(f"Total samples: {len(patch_sampled)}")
print(f"Unique classes in sampled data: {np.unique(patch_sampled['cls'])}")

fig = patch_overlay_wsi(patch_sampled, wsi_pt, patch_size, figsize=(9, 5.5))
# Out:
# Total samples: 3120
# Unique classes in sampled data: [1 2 3]

# %% [markdown]
# ### Alternatively, using TC_1024

# %%
IMAGE_SIZE = (1024, 1024)
model_weights = './data/TC_1024px.h5'
model1024 = get_TC(model_weights, image_size=IMAGE_SIZE, num_classes=3, output_features=False)

patch_size, _ = parse_patch_size(wsi, patch_size_microns=256)
TC_maskpt = os.path.join(output_dir, f"{wsi_name}_TC_1024_probmask.npy")
tissue_map1024 = run_TC_one_slide(wsi, mask_pt, TC_maskpt, patch_size, foreground_thes, IMAGE_SIZE, model=model1024, free_space=False, use_multithreading=True, max_workers=8)

tissue_map1024[:, :, [1, 2]] = tissue_map1024[:, :, [2, 1]]
plt.imshow(tissue_map1024)
plt.axis('off')
# Out:
# /cephfs/volumes/hpc_data_prj/cb_histology_data/8b8186f5-4ae0-4605-94c4-46d4ff4e62b0/Siyuan/Docker_test/nbtclassifier/NBT-Classifier/utils.py:41: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   net = MobileNet(include_top=False, input_shape=(image_size[0], image_size[1], 3))
# Mask saved at ../examples/17064108_FPE_1.ndpi_mask_use.npy.
# Preprocessing ../project/FEATUREs/17064108_FPE_1/17064108_FPE_1_TC_1024...
# Extracting patches from 17064108_FPE_1_TC_1024_pattern: 100%|████████| 4702/4702 [03:35<00:00, 21.77it/s]
# Tiles extracted for 17064108_FPE_1_TC_1024_pattern: 4702 patches saved.
# Vectorization completed for ../project/FEATUREs/17064108_FPE_1/17064108_FPE_1_TC_1024.
# Predicting tissue classes...
# /scratch/users/k21066795/conda/nbtclassifier/lib/python3.9/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 587/588 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 2025-05-06 12:12:58.468831: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_667', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-05-06 12:12:58.646676: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_674', 212 bytes spill stores, 236 bytes spill loads
#
# 2025-05-06 12:12:58.799234: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_667_0', 184 bytes spill stores, 412 bytes spill loads
#
# 2025-05-06 12:12:58.854259: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_667', 136 bytes spill stores, 136 bytes spill loads
#
# 2025-05-06 12:12:58.872756: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_681', 272 bytes spill stores, 272 bytes spill loads
#
# 2025-05-06 12:12:59.098794: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_667', 4368 bytes spill stores, 4344 bytes spill loads
#
# 2025-05-06 12:12:59.220402: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_674', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-05-06 12:12:59.245673: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_674_0', 212 bytes spill stores, 416 bytes spill loads
#
# 2025-05-06 12:12:59.248651: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_674', 4880 bytes spill stores, 6024 bytes spill loads
#
# 2025-05-06 12:12:59.301724: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_681', 220 bytes spill stores, 220 bytes spill loads
#
# 2025-05-06 12:12:59.372453: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_667', 3852 bytes spill stores, 3848 bytes spill loads
#
# 2025-05-06 12:12:59.570022: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_674', 2536 bytes spill stores, 2532 bytes spill loads
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 130s 200ms/step
# Processing Patches: 100%|███████████████████████████████████████| 4702/4702 [00:00<00:00, 1186120.01it/s]
# Tissue map saved at ../project/FEATUREs/17064108_FPE_1/17064108_FPE_1_TC_1024_probmask.npy.
# (-0.5, 135.5, 96.5, -0.5)
